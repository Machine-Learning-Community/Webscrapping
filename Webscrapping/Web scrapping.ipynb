# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

pd.set_option('display.max.columns', None)
print('setup complete')
# Out:
# setup complete

# %%
# get the html page
page = requests.get("https://www.must.ac.ke/kuccps-2019-admission-list-2/")
soup = BeautifulSoup(page.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://www.must.ac.ke/xmlrpc.php" rel="pingback"/>
# <script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
# <script>var et_site_url='https://www.must.ac.ke';var et_post_id='11667';function et_core_page_resource_fallback(a,b){"undefined"===typeof b&&(b=a.sheet.cssRules&&0===a.sheet.cssRules.length);b&&(a.onerror=null,a.onload=null,a.href?a.href=et_site_url+"/?et_core_page_resource="+a.id+et_post_id:a.src&&(a.src=et_site_url+"/?et_core_page_resource="+a.id+et_post_id))}
# </script><meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <!-- This site is optimized with the Yoast SEO plugin v17.3 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>KUCCPS 2019 Admission List - Meru University of Science and Technology</title>
# <link href="https://www.must.ac.ke/kuccps-2019-admission-list-2/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="KUCCPS 2019 Admission List - Meru University of Science and Technology" property="og:title"/>
# <meta content="On this link you will find the list of 2019 KUCCPS students who have been admitted to Meru University of Science and Technology." property="og:description"/>
# <meta content="https://www.must.ac.ke/kuccps-2019-admission-list-2/" property="og:url"/>
# <meta content="Meru University of Science and Technology" property="og:site_name"/>
# <meta content="https://www.facebook.com/MeruUniversity" property="article:publisher"/>
# <meta content="2019-04-24T11:14:23+00:00" property="article:published_time"/>
# <meta content="2019-07-03T13:58:59+00:00" property="article:modified_time"/>
# <meta content="https://i2.wp.com/www.must.ac.ke/wp-content/uploads/2019/04/admission-2019.jpg?fit=796%2C438&amp;ssl=1" property="og:image"/>
# <meta content="796" property="og:image:width"/>
# <meta content="438" property="og:image:height"/>
# <meta content="Written by" name="twitter:label1"/>
# <meta content="MUST" name="twitter:data1"/>
# <meta content="Est. reading time" name="twitter:label2"/>
# <meta content="62 minutes" name="twitter:data2"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://www.must.ac.ke/#website","url":"https://www.must.ac.ke/","name":"Meru University of Science and Technology","description":"Foundation of Innovations","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.must.ac.ke/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://www.must.ac.ke/kuccps-2019-admission-list-2/#primaryimage","inLanguage":"en-US","url":"https://i2.wp.com/www.must.ac.ke/wp-content/uploads/2019/04/admission-2019.jpg?fit=796%2C438&ssl=1","contentUrl":"https://i2.wp.com/www.must.ac.ke/wp-content/uploads/2019/04/admission-2019.jpg?fit=796%2C438&ssl=1","width":796,"height":438},{"@type":"WebPage","@id":"https://www.must.ac.ke/kuccps-2019-admission-list-2/#webpage","url":"https://www.must.ac.ke/kuccps-2019-admission-list-2/","name":"KUCCPS 2019 Admission List - Meru University of Science and Technology","isPartOf":{"@id":"https://www.must.ac.ke/#website"},"primaryImageOfPage":{"@id":"https://www.must.ac.ke/kuccps-2019-admission-list-2/#primaryimage"},"datePublished":"2019-04-24T11:14:23+00:00","dateModified":"2019-07-03T13:58:59+00:00","author":{"@id":"https://www.must.ac.ke/#/schema/person/e54c2f85a28c4ccb5391f3fbd868aa0d"},"breadcrumb":{"@id":"https://www.must.ac.ke/kuccps-2019-admission-list-2/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://www.must.ac.ke/kuccps-2019-admission-list-2/"]}]},{"@type":"BreadcrumbList","@id":"https://www.must.ac.ke/kuccps-2019-admission-list-2/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.must.ac.ke/"},{"@type":"ListItem","position":2,"name":"KUCCPS 2019 Admission List"}]},{"@type":"Person","@id":"https://www.must.ac.ke/#/schema/person/e54c2f85a28c4ccb5391f3fbd868aa0d","name":"MUST","url":"https://www.must.ac.ke/author/meruniversity/"}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="//v0.wordpress.com" rel="dns-prefetch"/>
# <link href="//i0.wp.com" rel="dns-prefetch"/>
# <link href="//i1.wp.com" rel="dns-prefetch"/>
# <link href="//i2.wp.com" rel="dns-prefetch"/>
# <link href="https://www.must.ac.ke/feed/" rel="alternate" title="Meru University of Science and Technology » Feed" type="application/rss+xml"/>
# <link href="https://www.must.ac.ke/comments/feed/" rel="alternate" title="Meru University of Science and Technology » Comments Feed" type="application/rss+xml"/>
# <link href="https://www.must.ac.ke/kuccps-2019-admission-list-2/feed/" rel="alternate" title="Meru University of Science and Technology » KUCCPS 2019 Admission List Comments Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.must.ac.ke\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.8.1"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([10084,65039,8205,55357,56613],[10084,65039,8203,55357,56613])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <meta content="MUST280521 v.4.9.4" name="generator"/><style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://www.must.ac.ke/wp-includes/css/dist/block-library/style.min.css?ver=5.8.1" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="wp-block-library-inline-css" type="text/css">
# .has-text-align-justify{text-align:justify;}
# </style>
# <link href="https://www.must.ac.ke/wp-includes/js/mediaelement/mediaelementplayer-legacy.min.css?ver=4.2.16" id="mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.must.ac.ke/wp-includes/js/mediaelement/wp-mediaelement.min.css?ver=5.8.1" id="wp-mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.must.ac.ke/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.4.2" id="contact-form-7-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.must.ac.ke/wp-content/plugins/wp-pagenavi/pagenavi-css.css?ver=2.70" id="wp-pagenavi-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300italic,400italic,600italic,700italic,800italic,400,300,600,700,800&amp;subset=latin,latin-ext&amp;display=swap" id="divi-fonts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.must.ac.ke/wp-content/themes/280521/style.css?ver=4.9.4" id="divi-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Merriweather:300,300italic,regular,italic,700,700italic,900,900italic&amp;subset=latin,latin-ext&amp;display=swap" id="et-builder-googlefonts-cached-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.must.ac.ke/wp-includes/css/dashicons.min.css?ver=5.8.1" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.must.ac.ke/wp-content/plugins/jetpack/css/jetpack.css?ver=10.2" id="jetpack_css-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jetpack_related-posts-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var related_posts_js_options = {"post_heading":"h4"};
# /* ]]> */
# </script>
# <script id="jetpack_related-posts-js" src="https://www.must.ac.ke/wp-content/plugins/jetpack/_inc/build/related-posts/related-posts.min.js?ver=20210930" type="text/javascript"></script>
# <script id="jquery-core-js" src="https://www.must.ac.ke/wp-includes/js/jquery/jquery.min.js?ver=3.6.0" type="text/javascript"></script>
# <script id="jquery-migrate-js" src="https://www.must.ac.ke/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2" type="text/javascript"></script>
# <link href="https://www.must.ac.ke/wp-json/" rel="https://api.w.org/"/><link href="https://www.must.ac.ke/wp-json/wp/v2/posts/11667" rel="alternate" type="application/json"/><link href="https://www.must.ac.ke/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.must.ac.ke/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.8.1" name="generator"/>
# <link href="https://wp.me/p7HH48-32b" rel="shortlink"/>
# <link href="https://www.must.ac.ke/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.must.ac.ke%2Fkuccps-2019-admission-list-2%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://www.must.ac.ke/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.must.ac.ke%2Fkuccps-2019-admission-list-2%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <meta content="Site Kit by Google 1.42.0" name="generator"/><script type="text/javascript">
# (function(url){
# 	if(/(?:Chrome\/26\.0\.1410\.63 Safari\/537\.31|WordfenceTestMonBot)/.test(navigator.userAgent)){ return; }
# 	var addEvent = function(evt, handler) {
# 		if (window.addEventListener) {
# 			document.addEventListener(evt, handler, false);
# 		} else if (window.attachEvent) {
# 			document.attachEvent('on' + evt, handler);
# 		}
# 	};
# 	var removeEvent = function(evt, handler) {
# 		if (window.removeEventListener) {
# 			document.removeEventListener(evt, handler, false);
# 		} else if (window.detachEvent) {
# 			document.detachEvent('on' + evt, handler);
# 		}
# 	};
# 	var evts = 'contextmenu dblclick drag dragend dragenter dragleave dragover dragstart drop keydown keypress keyup mousedown mousemove mouseout mouseover mouseup mousewheel scroll'.split(' ');
# 	var logHuman = function() {
# 		if (window.wfLogHumanRan) { return; }
# 		window.wfLogHumanRan = true;
# 		var wfscr = document.createElement('script');
# 		wfscr.type = 'text/javascript';
# 		wfscr.async = true;
# 		wfscr.src = url + '&r=' + Math.random();
# 		(document.getElementsByTagName('head')[0]||document.getElementsByTagName('body')[0]).appendChild(wfscr);
# 		for (var i = 0; i < evts.length; i++) {
# 			removeEvent(evts[i], logHuman);
# 		}
# 	};
# 	for (var i = 0; i < evts.length; i++) {
# 		addEvent(evts[i], logHuman);
# 	}
# })('//www.must.ac.ke/?wordfence_lh=1&hid=91DA0FB20B3E0CAFC87DB9C0C86887DE');
# </script><style type="text/css">img#wpstats{display:none}</style>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/><link as="font" crossorigin="anonymous" href="https://www.must.ac.ke/wp-content/themes/280521/core/admin/fonts/modules.ttf" rel="preload"/><link href="https://www.must.ac.ke/wp-content/uploads/2014/09/favicon.ico" rel="shortcut icon"/><script type="text/javascript">
#  (function($) {
#    $(document).ready(function(){
#
# $(".et-search-field").attr("placeholder", "What Can’t You Find?");
#    });
# })(jQuery);
#
# </script><link href="https://www.must.ac.ke/wp-content/et-cache/11667/et-core-unified-11667-16328249036008.min.css" id="et-core-unified-11667-cached-inline-styles" onerror="et_core_page_resource_fallback(this, true)" onload="et_core_page_resource_fallback(this)" rel="stylesheet"/><!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-54758690-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-54758690-1');
# </script>
# </head>
# <body class="post-template-default single single-post postid-11667 single-format-standard et_color_scheme_green et_pb_button_helper_class et_fixed_nav et_show_nav et_pb_show_title et_secondary_nav_enabled et_primary_nav_dropdown_animation_fade et_secondary_nav_dropdown_animation_fade et_header_style_left et_pb_footer_columns4 et_cover_background et_pb_gutter et_pb_gutters3 et_pb_pagebuilder_layout et_right_sidebar et_divi_theme et-db et_minified_js et_minified_css">
# <div id="page-container">
# <div id="top-header">
# <div class="container clearfix">
# <div id="et-secondary-menu">
# <ul class="et-social-icons">
# <li class="et-social-icon et-social-facebook">
# <a class="icon" href="https://www.facebook.com/MeruUniversity/">
# <span>Facebook</span>
# </a>
# </li>
# <li class="et-social-icon et-social-twitter">
# <a class="icon" href="https://twitter.com/MeruUniversity">
# <span>Twitter</span>
# </a>
# </li>
# <li class="et-social-icon et-social-instagram">
# <a class="icon" href="https://www.instagram.com/meru_university/">
# <span>Instagram</span>
# </a>
# </li>
# </ul><ul class="menu" id="et-secondary-nav"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2818"><a href="#">Student</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11992"><a href="https://www.must.ac.ke/2018-fee-structure/%20">Fee Structure</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11846"><a href="https://www.must.ac.ke/timetables/">Timetables</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-12327"><a>Semester Dates</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-16665"><a href="https://www.must.ac.ke/wp-content/uploads/2021/09/SEMESTER-DATES.pdf">2020-2021 &amp; 2021-2022 Academic Year</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-16995"><a href="https://www.must.ac.ke/wp-content/uploads/2021/07/Semester-dates-for-Nursing-and-Clinical-Medicine-Community-Health.pdf">Semester Dates for Nursing and Clinical Medicine &amp; Community Health</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-16785"><a href="https://www.must.ac.ke/wp-content/uploads/2021/06/SEMESTER-DATES-FOR-BSC.-NURSING.pdf">Semester Dates for Bsc. Nursing</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-15622"><a href="https://www.must.ac.ke/category/career-services/">Office of Career Services</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-15042"><a href="https://www.must.ac.ke/the-office-of-the-dean-of-students/">Dean of Students</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-11561"><a href="#">Prospective Students</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-17711"><a href="https://www.must.ac.ke/schools-departments-and-programmes/">Choose a Course</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-14181"><a href="https://www.must.ac.ke/schools-departments-and-programmes/">Academic Programmes</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-17712"><a href="https://admission.must.ac.ke/" rel="noopener" target="_blank">Application Process</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11564"><a href="https://www.must.ac.ke/accomodation/">Accomodation</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11248"><a href="https://student.must.ac.ke/" rel="noopener" target="_blank">Student Portal</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11249"><a href="https://mail.google.com/a/must.ac.ke" rel="noopener" target="_blank">Student Email</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-11255"><a href="#">Clubs &amp; Societies</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12005"><a href="https://www.must.ac.ke/mustec/">MUSTEC</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12006"><a href="https://www.must.ac.ke/musof/">MUSOF</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12007"><a href="https://www.must.ac.ke/masmu/">MASMU</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12008"><a href="https://www.must.ac.ke/muhec/">MUHEC</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12009"><a href="https://www.must.ac.ke/mupec/">MUPEC</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12010"><a href="https://www.must.ac.ke/equity-leaders-club/">Equity Leaders Club</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12011"><a href="https://www.must.ac.ke/food-science-club/">Food Science Club</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12012"><a href="https://www.must.ac.ke/animal-health-club/">Animal Health Club</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11256"><a href="https://www.must.ac.ke/accomodation/">Accommodation</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11258"><a href="https://www.must.ac.ke/downloads/">Downloads</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11260"><a href="https://library.must.ac.ke/" rel="noopener" target="_blank">Library</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11640"><a href="https://www.must.ac.ke/contacts/">Contact Us</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-3021"><a href="#" rel="noopener" target="_blank">Staff</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11261"><a href="https://staff.must.ac.ke/" rel="noopener" target="_blank">Portal</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11262"><a href="https://mail.google.com/a/must.ac.ke" rel="noopener" target="_blank">Email</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-12067"><a href="https://www.must.ac.ke/downloads/">Downloads</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-12054"><a href="https://www.must.ac.ke/performancecontract/">Performance Contract</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-13666"><a href="https://www.must.ac.ke/timetables/">Timetables</a></li>
# </ul>
# </li>
# </ul> </div> <!-- #et-secondary-menu -->
# </div> <!-- .container -->
# </div> <!-- #top-header -->
# <header data-height-onload="66" id="main-header">
# <div class="container clearfix et_menu_container">
# <div class="logo_container">
# <span class="logo_helper"></span>
# <a href="https://www.must.ac.ke/">
# <img alt="Meru University of Science and Technology" data-height-percentage="54" id="logo" src="https://www.must.ac.ke/wp-content/uploads/2019/04/logo.png"/>
# </a>
# </div>
# <div data-fixed-height="40" data-height="66" id="et-top-navigation">
# <nav id="top-menu-nav">
# <ul class="nav" id="top-menu"><li class="mega-menu menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-6701" id="menu-item-6701"><a href="#">Schools</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6702" id="menu-item-6702"><a href="https://safs.must.ac.ke/" rel="noopener" target="_blank">School of Agriculture &amp; Food Science</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-11844" id="menu-item-11844"><a href="https://www.must.ac.ke/sbe/">School of Business and Economics</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6703" id="menu-item-6703"><a href="https://www.must.ac.ke/site/">School of Computing &amp; Informatics</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6709" id="menu-item-6709"><a href="https://www.must.ac.ke/sed/">School of Education</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6704" id="menu-item-6704"><a href="https://www.must.ac.ke/school-engineering-architecture/">School of Engineering &amp; Architecture</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6706" id="menu-item-6706"><a href="https://www.must.ac.ke/shs-2/">School of Health Sciences</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7550" id="menu-item-7550"><a href="https://www.must.ac.ke/school-of-nursing/">School of Nursing</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6708" id="menu-item-6708"><a href="https://www.must.ac.ke/school-of-pure-and-applied-sciences-spas/">School of Pure &amp; Applied Sciences</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-13831" id="menu-item-13831"><a href="https://www.must.ac.ke/technical-and-vocational-education-and-training-tvet-programmes/">TVET</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-6730" id="menu-item-6730"><a href="#">About MUST</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-17265" id="menu-item-17265"><a href="https://www.must.ac.ke/category/covid-19/">COVID-19 Information</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6734" id="menu-item-6734"><a href="https://www.must.ac.ke/about-us/">MUST Profile</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6737" id="menu-item-6737"><a href="https://www.must.ac.ke/visionmission-and-core-values/">Vision, Mission &amp; Core Values</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-14321" id="menu-item-14321"><a href="#">Leadership</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6747" id="menu-item-6747"><a href="https://www.must.ac.ke/chancellor/">Chancellor</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-14291" id="menu-item-14291"><a href="https://www.must.ac.ke/must-council-members/">University Council</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6748" id="menu-item-6748"><a href="https://www.must.ac.ke/management/">Management Board</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-13386" id="menu-item-13386"><a href="https://www.must.ac.ke/must-service-charter/">Service Charter</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6739" id="menu-item-6739"><a href="https://www.must.ac.ke/quality-policy/">Quality Policy</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-13381" id="menu-item-13381"><a href="https://www.must.ac.ke/national-cohesion/">National Cohesion</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-12056" id="menu-item-12056"><a href="https://www.must.ac.ke/genderdisability-and-mainstreaming/">Gender,Disability &amp; Mainstreaming</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-14323" id="menu-item-14323"><a href="#">MUST Media</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11230" id="menu-item-11230"><a href="#">Gallery</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-12867" id="menu-item-12867"><a href="https://www.must.ac.ke/graduation-magazines/">Magazines</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6738" id="menu-item-6738"><a href="https://www.must.ac.ke/directions/">Directions</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-14779" id="menu-item-14779"><a href="https://www.must.ac.ke/hiv-aids/">HIV AIDS</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-11216" id="menu-item-11216"><a href="#">Join Us</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-16547" id="menu-item-16547"><a href="https://www.must.ac.ke/wp-content/uploads/2021/05/MUST-Courses-Brochure-2020-2021.pdf">Programmes Brochure</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11233" id="menu-item-11233"><a href="https://www.must.ac.ke/schools-departments-and-programmes/">Choose a Course</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-17256" id="menu-item-17256"><a href="https://admission.must.ac.ke/" rel="noopener" target="_blank">Application Process</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11235" id="menu-item-11235"><a href="https://www.must.ac.ke/downloads/">Application Forms</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-16536" id="menu-item-16536"><a href="https://admission.must.ac.ke/" rel="noopener" target="_blank">Online Course Application</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-6756" id="menu-item-6756"><a href="#">MUST Campus</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-17535" id="menu-item-17535"><a href="#">ISMS/ISO</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-16988" id="menu-item-16988"><a href="https://must.dimensionplus.co.ke/" rel="noopener" target="_blank">ISO/ISMS</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-17529" id="menu-item-17529"><a href="https://www.must.ac.ke/must-information-security-policy-statement/">MUST INFORMATION SECURITY POLICY STATEMENT</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-16099" id="menu-item-16099"><a href="https://www.must.ac.ke/category/careers/">Careers</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-15555" id="menu-item-15555"><a href="https://www.must.ac.ke/category/must-diary/">MUST Diary</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-11239" id="menu-item-11239"><a href="https://www.must.ac.ke">Main Campus</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11236" id="menu-item-11236"><a href="https://www.must.ac.ke/town-campus2/">Town Campus</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11238" id="menu-item-11238"><a href="https://www.must.ac.ke/marimba/">Marimba</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12774" id="menu-item-12774"><a href="https://www.must.ac.ke/tvet/">TVET</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-12055" id="menu-item-12055"><a href="https://library.must.ac.ke/">Library</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11242" id="menu-item-11242"><a href="https://www.must.ac.ke/sports/">Sports</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-12733" id="menu-item-12733"><a href="https://www.must.ac.ke/iiec/">Innovation, Incubation &amp; Entrepreneurship Centre</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-12734" id="menu-item-12734"><a href="http://lms.must.ac.ke/" rel="noopener" target="_blank">LMS/ODeL</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-15485" id="menu-item-15485"><a href="https://www.must.ac.ke/internal-research-grants-database/">Research</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-12065" id="menu-item-12065"><a href="https://www.must.ac.ke/downloads/">Downloads</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-12083" id="menu-item-12083"><a href="#">ICT</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-16719" id="menu-item-16719"><a href="https://ict.must.ac.ke/" rel="noopener" target="_blank">ICT Home</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-16718" id="menu-item-16718"><a href="http://support.must.ac.ke:9765/portal" rel="noopener" target="_blank">Online User Support</a></li>
# </ul>
# </li>
# </ul> </nav>
# <div id="et_top_search">
# <span id="et_search_icon"></span>
# </div>
# <div id="et_mobile_nav_menu">
# <div class="mobile_nav closed">
# <span class="select_page">Select Page</span>
# <span class="mobile_menu_bar mobile_menu_bar_toggle"></span>
# </div>
# </div> </div> <!-- #et-top-navigation -->
# </div> <!-- .container -->
# <div class="et_search_outer">
# <div class="container et_search_form_container">
# <form action="https://www.must.ac.ke/" class="et-search-form" method="get" role="search">
# <input class="et-search-field" name="s" placeholder="Search …" title="Search for:" type="search" value=""/> </form>
# <span class="et_close_search_field"></span>
# </div>
# </div>
# </header> <!-- #main-header -->
# <div id="et-main-area">
# <div id="main-content">
# <div class="container">
# <div class="clearfix" id="content-area">
# <div id="left-area">
# <article class="et_pb_post post-11667 post type-post status-publish format-standard has-post-thumbnail hentry category-campus-news" id="post-11667">
# <div class="et_post_meta_wrapper">
# <h1 class="entry-title">KUCCPS 2019 Admission List</h1>
ange() {
# 		if ( dropdown.options[ dropdown.selectedIndex ].value !== '' ) {
# 			document.location.href = this.options[ this.selectedIndex ].value;
# 		}
# 	}
# 	dropdown.onchange = onSelectChange;
# })();
# /* ]]> */
# </script>
# </div> <!-- end .et_pb_widget --><div class="et_pb_widget widget_nav_menu" id="nav_menu-14"><h4 class="widgettitle">Prospective Students</h4><div class="menu-prospective-students-container"><ul class="menu" id="menu-prospective-students"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4381" id="menu-item-4381"><a href="https://www.must.ac.ke/2018-september-intake/">Next Intake</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11168" id="menu-item-11168"><a href="https://www.must.ac.ke/school-of-pure-and-applied-sciences-spas/">New Courses</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-702" id="menu-item-702"><a href="https://www.must.ac.ke/about-us-2/">Our Profile</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-703" id="menu-item-703"><a href="https://www.must.ac.ke/academic-programmes/">Academic Programmes</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-704" id="menu-item-704"><a href="https://www.must.ac.ke/application-procedure/">Application Procedure</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-705" id="menu-item-705"><a href="https://www.must.ac.ke/directions/">Directions</a></li>
# </ul></div></div> <!-- end .et_pb_widget --><div class="et_pb_widget widget_nav_menu" id="nav_menu-15"><h4 class="widgettitle">Current Students</h4><div class="menu-current-students-container"><ul class="menu" id="menu-current-students"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9657" id="menu-item-9657"><a href="https://www.must.ac.ke/wp-content/uploads/2018/10/Semester-Dates-Oct-2018-june-2019.pdf">MSc. Environmental Science and Resource Mngt Semester dates</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9316" id="menu-item-9316"><a href="https://www.must.ac.ke/2019-semester-dates/">2018-2019 Semester Dates</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9300" id="menu-item-9300"><a href="https://www.must.ac.ke/2018-fee-structure/">2018 Fee Structure</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6288" id="menu-item-6288"><a href="https://www.must.ac.ke/student-online-units/">Register Units Online</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1615" id="menu-item-1615"><a href="http://library.must.ac.ke" rel="noopener" target="_blank">Library Website</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-691" id="menu-item-691"><a href="https://www.must.ac.ke/schools-departments-and-programmes/">Schools, Departments and Programmes</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3324" id="menu-item-3324"><a href="https://www.must.ac.ke/?page_id=2848">Marimba Learning Centre</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-692" id="menu-item-692"><a href="https://www.must.ac.ke/accomodation/">Accomodation</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-694" id="menu-item-694"><a href="https://www.must.ac.ke/important-links/">Important Links</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-695" id="menu-item-695"><a href="http://odel.must.ac.ke/">Distance Learning</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9311" id="menu-item-9311"><a href="https://www.must.ac.ke/payment-of-fee/">Payment of Fee</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-696" id="menu-item-696"><a href="https://mail.google.com/a/must.ac.ke">Email</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1556" id="menu-item-1556"><a href="http://cu.must.ac.ke" rel="noopener" target="_blank">Christian Union Website</a></li>
# </ul></div></div> <!-- end .et_pb_widget --><div class="et_pb_widget widget_text" id="text-6"><h4 class="widgettitle">Location</h4> <div class="textwidget"><p><iframe allowfullscreen="" frameborder="0" loading="lazy" src="https://www.google.com/maps/embed?pb=!1m14!1m8!1m3!1d1994.903628804034!2d37.708416!3d0.134925!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x0%3A0x94e1dbf4dfea47bd!2sMeru+University+of+Science+and+Technology!5e0!3m2!1sen!2sus!4v1557145841627!5m2!1sen!2sus" style="border:0"></iframe></p>
# </div>
# </div> <!-- end .et_pb_widget --> </div> <!-- end #sidebar -->
# </div> <!-- #content-area -->
# </div> <!-- .container -->
# </div> <!-- #main-content -->
# <span class="et_pb_scroll_top et-pb-icon"></span>
# <footer id="main-footer">
# <div class="container">
# <div class="clearfix" id="footer-widgets">
# <div class="footer-widget"><div class="fwidget et_pb_widget widget_text" id="text-3"><h4 class="title">MUST on Twitter</h4> <div class="textwidget"><p><a class="twitter-timeline" data-height="500" data-width="220" href="https://twitter.com/MeruUniversity?ref_src=twsrc%5Etfw">Tweets by MeruUniversity</a> <script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js"></script></p>
# </div>
# </div> <!-- end .fwidget --></div> <!-- end .footer-widget --><div class="footer-widget"><div class="fwidget et_pb_widget widget_text" id="text-4"><h4 class="title">MUST on Facebook</h4> <div class="textwidget"><div id="fb-root"></div>
# <p><script async="" crossorigin="anonymous" defer="" src="https://connect.facebook.net/en_US/sdk.js#xfbml=1&amp;version=v3.2"></script></p>
# <div class="fb-page" data-adapt-container-width="true" data-height="500" data-hide-cover="true" data-href="https://www.facebook.com/MeruUniversity/" data-show-facepile="true" data-small-header="true" data-tabs="timeline" data-width="220">
# <blockquote cite="https://www.facebook.com/MeruUniversity/" class="fb-xfbml-parse-ignore"><p><a href="https://www.facebook.com/MeruUniversity/">Meru University</a></p></blockquote>
# </div>
# </div>
# </div> <!-- end .fwidget --></div> <!-- end .footer-widget --><div class="footer-widget"><div class="fwidget et_pb_widget widget_text" id="text-2"><h4 class="title">Contact Us</h4> <div class="textwidget"><p><strong>P.O Box ,972-60200 Meru Kenya</strong></p>
# <p><strong> Phone: +254 712524293</strong></p>
# <p><strong>Email: info@must.ac.ke</strong></p>
# </div>
# </div> <!-- end .fwidget --><div class="fwidget et_pb_widget widget_text" id="text-5"> <div class="textwidget"><p><a href="https://www.must.ac.ke/complaintscompliments/"><img alt="" class="alignnone wp-image-11652 size-full" data-recalc-dims="1" height="972" loading="lazy" sizes="(max-width: 1080px) 100vw, 1080px" src="https://i1.wp.com/www.must.ac.ke/wp-content/uploads/2019/05/complaints-compliments.png?resize=1080%2C972&amp;ssl=1" srcset="https://i1.wp.com/www.must.ac.ke/wp-content/uploads/2019/05/complaints-compliments.png?w=1280&amp;ssl=1 1280w, https://i1.wp.com/www.must.ac.ke/wp-content/uploads/2019/05/complaints-compliments.png?resize=300%2C270&amp;ssl=1 300w, https://i1.wp.com/www.must.ac.ke/wp-content/uploads/2019/05/complaints-compliments.png?resize=768%2C691&amp;ssl=1 768w, https://i1.wp.com/www.must.ac.ke/wp-content/uploads/2019/05/complaints-compliments.png?resize=1024%2C922&amp;ssl=1 1024w, https://i1.wp.com/www.must.ac.ke/wp-content/uploads/2019/05/complaints-compliments.png?resize=1080%2C972&amp;ssl=1 1080w" width="1080"/></a></p>
# </div>
# </div> <!-- end .fwidget --><div class="fwidget et_pb_widget widget_text" id="text-8"> <div class="textwidget"><p><a href="https://www.must.ac.ke/reportcorruption/"><img alt="" class="alignnone size-full wp-image-12022" data-recalc-dims="1" height="98" loading="lazy" src="https://i0.wp.com/www.must.ac.ke/wp-content/uploads/2019/07/Report-Corruption.png?resize=300%2C98&amp;ssl=1" width="300"/></a></p>
# </div>
# </div> <!-- end .fwidget --></div> <!-- end .footer-widget --><div class="footer-widget"><div class="fwidget et_pb_widget widget_text" id="text-7"><h4 class="title">Location</h4> <div class="textwidget"><p><iframe allowfullscreen="" frameborder="0" loading="lazy" src="https://www.google.com/maps/embed?pb=!1m14!1m8!1m3!1d1994.903628804034!2d37.708416!3d0.134925!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x0%3A0x94e1dbf4dfea47bd!2sMeru+University+of+Science+and+Technology!5e0!3m2!1sen!2sus!4v1557145841627!5m2!1sen!2sus" style="border: 0;"></iframe></p>
# </div>
# </div> <!-- end .fwidget --><div class="fwidget et_pb_widget widget_blog_subscription jetpack_subscription_widget" id="blog_subscription-4"><h4 class="title">Subscribe to Updates via Email</h4>
# <form accept-charset="utf-8" action="#" id="subscribe-blog-blog_subscription-4" method="post">
# <div id="subscribe-text"><p>Enter your email address to subscribe to this website and receive notifications of new posts by email.</p>
# </div> <div class="jetpack-subscribe-count">
# <p>
# 						Join 3,251 other subscribers						</p>
# </div>
# <p id="subscribe-email">
# <label class="screen-reader-text" for="subscribe-field-blog_subscription-4" id="jetpack-subscribe-label">
# 							Email Address                        </label>
# <input id="subscribe-field-blog_subscription-4" name="email" placeholder="Email Address" required="required" type="email" value=""/>
# </p>
# <p id="subscribe-submit">
# <input name="action" type="hidden" value="subscribe"/>
# <input name="source" type="hidden" value="https://www.must.ac.ke/kuccps-2019-admission-list-2/"/>
# <input name="sub-type" type="hidden" value="widget"/>
# <input name="redirect_fragment" type="hidden" value="blog_subscription-4"/>
# <button class="wp-block-button__link" name="jetpack_subscriptions_widget" type="submit">
# 	                        Subscribe                        </button>
# </p>
# </form>
# </div> <!-- end .fwidget --></div> <!-- end .footer-widget --> </div> <!-- #footer-widgets -->
# </div> <!-- .container -->
# <div id="footer-bottom">
# <div class="container clearfix">
# <ul class="et-social-icons">
# <li class="et-social-icon et-social-facebook">
# <a class="icon" href="https://www.facebook.com/MeruUniversity/">
# <span>Facebook</span>
# </a>
# </li>
# <li class="et-social-icon et-social-twitter">
# <a class="icon" href="https://twitter.com/MeruUniversity">
# <span>Twitter</span>
# </a>
# </li>
# <li class="et-social-icon et-social-instagram">
# <a class="icon" href="https://www.instagram.com/meru_university/">
# <span>Instagram</span>
# </a>
# </li>
# </ul><div id="footer-info">
# Designed by Webmaster Meru University of Science &amp; Technology</div> </div> <!-- .container -->
# </div>
# </footer> <!-- #main-footer -->
# </div> <!-- #et-main-area -->
# </div> <!-- #page-container -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-54758690-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-54758690-1');
# </script><script id="jetpack-photon-js" src="https://www.must.ac.ke/wp-content/plugins/jetpack/_inc/build/photon/photon.min.js?ver=20191001" type="text/javascript"></script>
# <script id="regenerator-runtime-js" src="https://www.must.ac.ke/wp-includes/js/dist/vendor/regenerator-runtime.min.js?ver=0.13.7" type="text/javascript"></script>
# <script id="wp-polyfill-js" src="https://www.must.ac.ke/wp-includes/js/dist/vendor/wp-polyfill.min.js?ver=3.15.0" type="text/javascript"></script>
# <script id="contact-form-7-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"api":{"root":"https:\/\/www.must.ac.ke\/wp-json\/","namespace":"contact-form-7\/v1"}};
# /* ]]> */
# </script>
# <script id="contact-form-7-js" src="https://www.must.ac.ke/wp-content/plugins/contact-form-7/includes/js/index.js?ver=5.4.2" type="text/javascript"></script>
# <script id="comment-reply-js" src="https://www.must.ac.ke/wp-includes/js/comment-reply.min.js?ver=5.8.1" type="text/javascript"></script>
# <script id="divi-custom-script-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var DIVI = {"item_count":"%d Item","items_count":"%d Items"};
# var et_shortcodes_strings = {"previous":"Previous","next":"Next"};
# var et_pb_custom = {"ajaxurl":"https:\/\/www.must.ac.ke\/wp-admin\/admin-ajax.php","images_uri":"https:\/\/www.must.ac.ke\/wp-content\/themes\/280521\/images","builder_images_uri":"https:\/\/www.must.ac.ke\/wp-content\/themes\/280521\/includes\/builder\/images","et_frontend_nonce":"7227d9ab37","subscription_failed":"Please, check the fields below to make sure you entered the correct information.","et_ab_log_nonce":"0f0d39bcd3","fill_message":"Please, fill in the following fields:","contact_error_message":"Please, fix the following errors:","invalid":"Invalid email","captcha":"Captcha","prev":"Prev","previous":"Previous","next":"Next","wrong_captcha":"You entered the wrong number in captcha.","wrong_checkbox":"Checkbox","ignore_waypoints":"no","is_divi_theme_used":"1","widget_search_selector":".widget_search","ab_tests":[],"is_ab_testing_active":"","page_id":"11667","unique_test_id":"","ab_bounce_rate":"5","is_cache_plugin_active":"no","is_shortcode_tracking":"","tinymce_uri":""}; var et_builder_utils_params = {"condition":{"diviTheme":true,"extraTheme":false},"scrollLocations":["app","top"],"builderScrollLocations":{"desktop":"app","tablet":"app","phone":"app"},"onloadScrollLocation":"app","builderType":"fe"}; var et_frontend_scripts = {"builderCssContainerPrefix":"#et-boc","builderCssLayoutPrefix":"#et-boc .et-l"};
# var et_pb_box_shadow_elements = [];
# var et_pb_motion_elements = {"desktop":[],"tablet":[],"phone":[]};
# var et_pb_sticky_elements = [];
# /* ]]> */
# </script>
# <script id="divi-custom-script-js" src="https://www.must.ac.ke/wp-content/themes/280521/js/custom.unified.js?ver=4.9.4" type="text/javascript"></script>
# <script id="et-core-common-js" src="https://www.must.ac.ke/wp-content/themes/280521/core/admin/js/common.js?ver=4.9.4" type="text/javascript"></script>
# <script id="wp-embed-js" src="https://www.must.ac.ke/wp-includes/js/wp-embed.min.js?ver=5.8.1" type="text/javascript"></script>
# <script id="jetpack-subscriptions-js-js" src="https://www.must.ac.ke/wp-content/plugins/jetpack/modules/subscriptions/subscriptions.js?ver=10.2" type="text/javascript"></script>
# <script defer="" src="https://stats.wp.com/e-202140.js"></script>
# <script>
# 	_stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:10.2',blog:'113848004',post:'11667',tz:'3',srv:'www.must.ac.ke'} ]);
# 	_stq.push([ 'clickTrackerInit', '113848004', '11667' ]);
# </script>
# </body>
# </html>

# %%
# get the table

table = soup.find('table')

headers = []

for rows in table.find_all('tr')[:1]:
    data = rows.find_all('td')
    titles = [td.text.strip() for td in data]
    headers.append(titles)
df =pd.DataFrame(columns = headers)
df
# Out:
# Empty DataFrame
# Columns: [(S.No,), (Index Number/Year,), (Student Name,), (Programme Code,), (Programme Name,)]
# Index: []

# %%
# getting the table content

for row in table.find_all('tr')[1:]:
    row_data = row.find_all('td')
    content = [td.text for td in row_data]
    length = len(df)
    df.loc[length]=content
    
df
# Out:
#       S.No Index Number/Year             Student Name Programme Code  \
# 0        1  04125110001/2018      MWALIMU KINDA DHIMA        1240107
# 1        2  07209108027/2018     MAINGI KARIITHI JOHN        1240107
# 2        3  07215223012/2018  GITHINJI MARTIN GITONGA        1240107
# 3        4  08202001116/2018       KIBIRA JAMES GAITA        1240107
# 4        5  08210201007/2018       WERU LILIAN WAMBUI        1240107
# ...    ...               ...                      ...            ...
# 1494  1495  40735206193/2018     BONUKE BARONGO TONNY        1240732
# 1495  1496  40745120017/2018  ONDIEKI MONYANGI SHARON        1240732
# 1496  1497  42725210022/2018             ODUOR NEWTON        1240732
# 1497  1498  42738120012/2018    OCHIENG BENARD OTIENO        1240732
# 1498  1499  45800001031/2018    ABDIFATAH  HASSAN ALI        1240732
#
#                                Programme Name
# 0     BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
# 1     BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
# 2     BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
# 3     BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
# 4     BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
# ...                                       ...
# 1494      BACHELOR OF SCIENCE (PUBLIC HEALTH)
# 1495      BACHELOR OF SCIENCE (PUBLIC HEALTH)
# 1496      BACHELOR OF SCIENCE (PUBLIC HEALTH)
# 1497      BACHELOR OF SCIENCE (PUBLIC HEALTH)
# 1498      BACHELOR OF SCIENCE (PUBLIC HEALTH)
#
# [1499 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv('2019admission.csv')

# %%
data = pd.read_csv('2019admission.csv')
data.head()
# Out:
#    Unnamed: 0  S.No Index Number/Year             Student Name  \
# 0           0     1  04125110001/2018      MWALIMU KINDA DHIMA
# 1           1     2  07209108027/2018     MAINGI KARIITHI JOHN
# 2           2     3  07215223012/2018  GITHINJI MARTIN GITONGA
# 3           3     4  08202001116/2018       KIBIRA JAMES GAITA
# 4           4     5  08210201007/2018       WERU LILIAN WAMBUI
#
#    Programme Code                           Programme Name
# 0         1240107  BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
# 1         1240107  BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
# 2         1240107  BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
# 3         1240107  BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
# 4         1240107  BACHELOR OF SCIENCE (ACTUARIAL SCIENCE)
